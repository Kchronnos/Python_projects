# %%
import requests
import json

# To set your environment variables in your terminal run the following line:
bearer_token ='AAAAAAAAAAAAAAAAAAAAAAl7PQEAAAAAyRv3MEYBWVI7UjBbpmltHNSEUEU%3DFNouxOIdysh57Jc4VIa6TqQxbc9qe3j7Nof1I0CESyAPzHLWK8'


search_url = "https://api.twitter.com/2/tweets/search/all"

# Optional params: start_time,end_time,since_id,until_id,max_results,next_token,
# expansions,tweet.fields,media.fields,poll.fields,place.fields,user.fields
query_params = {'query': '#bitcoin', 'start_time': '2021-03-13T00:00:00Z', 'end_time':'2021-03-14T00:00:00Z', 'max_results':'10', 
                'tweet.fields' : 'author_id,conversation_id,created_at,geo,in_reply_to_user_id,lang,public_metrics' ,
                'user.fields':'public_metrics,verified'}


def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers


def connect_to_endpoint(url, headers, params):
    response = requests.request("GET", search_url, headers=headers, params=params)
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()


def main():
    headers = create_headers(bearer_token)
    global json_response
    json_response = connect_to_endpoint(search_url, headers, query_params)
    print(json.dumps(json_response, indent=4, sort_keys=True))

# %%
https://api.twitter.com/2/users/2244994945/tweets?tweet.fields=created_at&max_results=100&start_time=2019-01-01T17:00:00Z&end_time=2020-12-12T01:00:00Z

# %%
if __name__ == "__main__":
    main()
# Out:
# 200
# {
#     "data": [
#         {
#             "author_id": "2288672472",
#             "conversation_id": "1370887390412279809",
#             "created_at": "2021-03-13T23:59:58.000Z",
#             "id": "1370887390412279809",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 184
#             },
#             "text": "RT @stoolpresidente: Bitcoin Emergency Press Conference 2 - On Second Thought I Guess I Did Okay Sticking With What I Know This Year $penn\u2026"
#         },
#         {
#             "author_id": "436065951",
#             "conversation_id": "1370887389820956678",
#             "created_at": "2021-03-13T23:59:58.000Z",
#             "id": "1370887389820956678",
#             "lang": "en",
#             "public_metrics": {
#                 "like_count": 2,
#                 "quote_count": 1,
# ...

# %%
json_response
# Out:
# {'data': [{'author_id': '2288672472',
#    'conversation_id': '1370887390412279809',
#    'created_at': '2021-03-13T23:59:58.000Z',
#    'id': '1370887390412279809',
#    'lang': 'en',
#    'public_metrics': {'like_count': 0,
#     'quote_count': 0,
#     'reply_count': 0,
#     'retweet_count': 185},
#    'text': 'RT @stoolpresidente: Bitcoin Emergency Press Conference 2 - On Second Thought I Guess I Did Okay Sticking With What I Know This Year $penn…'},
#   {'author_id': '436065951',
#    'conversation_id': '1370887389820956678',
#    'created_at': '2021-03-13T23:59:58.000Z',
#    'id': '1370887389820956678',
#    'lang': 'en',
#    'public_metrics': {'like_count': 2,
#     'quote_count': 1,
#     'reply_count': 0,
#     'retweet_count': 0},
#    'text': 'Onde indoeuropee 12 #bitcoin #CPCP #ElonMusk \nhttps://t.co/Zsun3P4NNa'},
#   {'author_id': '1306502575181541379',
#    'conversation_id': '1370887385043582980',
#    'created_at': '2021-03-13T23:59:57.000Z',
# ...

# %%
type(json_response)
# Out:
# dict

# %%
json_response['data']
# Out:
# [{'author_id': '2288672472',
#   'conversation_id': '1370887390412279809',
#   'created_at': '2021-03-13T23:59:58.000Z',
#   'id': '1370887390412279809',
#   'lang': 'en',
#   'public_metrics': {'like_count': 0,
#    'quote_count': 0,
#    'reply_count': 0,
#    'retweet_count': 185},
#   'text': 'RT @stoolpresidente: Bitcoin Emergency Press Conference 2 - On Second Thought I Guess I Did Okay Sticking With What I Know This Year $penn…'},
#  {'author_id': '436065951',
#   'conversation_id': '1370887389820956678',
#   'created_at': '2021-03-13T23:59:58.000Z',
#   'id': '1370887389820956678',
#   'lang': 'en',
#   'public_metrics': {'like_count': 2,
#    'quote_count': 1,
#    'reply_count': 0,
#    'retweet_count': 0},
#   'text': 'Onde indoeuropee 12 #bitcoin #CPCP #ElonMusk \nhttps://t.co/Zsun3P4NNa'},
#  {'author_id': '1306502575181541379',
#   'conversation_id': '1370887385043582980',
#   'created_at': '2021-03-13T23:59:57.000Z',
#   'id': '1370887385043582980',
#   'lang': 'en',
# ...

# %%
import pandas as pd

# %%
response = pd.DataFrame.from_dict(json_response['data'])

# %%
response
# Out:
#        conversation_id  ...  in_reply_to_user_id
# 0  1370887390412279809  ...                  NaN
# 1  1370887389820956678  ...                  NaN
# 2  1370887385043582980  ...                  NaN
# 3  1370887379888771072  ...                  NaN
# 4  1370887374016806912  ...  1331332314786385920
# 5  1370887372376842245  ...                  NaN
# 6  1370887055186739201  ...             91478624
# 7  1370887365280075776  ...                  NaN
# 8  1370887364936089606  ...                  NaN
# 9  1370887362193022977  ...                  NaN
#
# [10 rows x 8 columns]
